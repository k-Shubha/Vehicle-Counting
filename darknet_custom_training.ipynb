# %% [markdown]
# <a href="https://colab.research.google.com/github/k-Shubha/Vehicle-Counting/blob/master/darknet_custom_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get upgrade
# !apt-get install build-essential
# !apt-get install cmake git libgtk2.0-dev pkg-config libavcodec-dev libavformat-dev libswscale-dev
# !apt-get install libavcodec-dev libavformat-dev libswscale-d
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran35/ InRelease [3,626 B]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Ign:3 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:4 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [564 B]
# Get:5 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:6 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release [564 B]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Get:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release.gpg [833 B]
# Hit:9 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# ...

# %%
# !apt-get -y install cmake
# !which cmake

# !cmake --version
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.10.2-1ubuntu2.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.
# /usr/local/bin/cmake
# cmake version 3.12.0
#
# CMake suite maintained and supported by Kitware (kitware.com/cmake).

# %%
# !apt-get install libopencv-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 8 not upgraded.

# %%
#code to mount drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
#code to import files from drive and to save files into the drive

sourceDir = '/content/drive/My Drive/darknet_4000.zip'

destDir =  '/content'
shutil.copy(sourceDir, destDir)
# Out:
# '/content/darknet_4000.zip'

# %%
# %cd /content/
# Out:
# /content

# %%
#code to unzip files
from zipfile import ZipFile
file_name = "darknet.zip"


with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')
# Out:
# Done

# %%
#code to remove files
import shutil

shutil.rmtree('/content/darknet')

# %%
cd /content

# %%
from zipfile import ZipFile
file_name = "All_images.zip"


with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')

# %%
import shutil 

sourceDir = '/content/All_images/'
destDir =  '/content/darknet/build/darknet/x64/data/obj/'
shutil.move(sourceDir, destDir)

# %%
import shutil 

sourceDir = '/content/obj.names'
destDir =  '/content/darknet/build/darknet/x64/data/'
shutil.move(sourceDir, destDir)

# %%
import shutil 

sourceDir = '/content/yolov3-obj.cfg'
destDir =  '/content/darknet/build/darknet/x64/'
shutil.move(sourceDir, destDir)

# %%
# !git clone https://github.com/AlexeyAB/darknet/

# %%
#actually successfuly modified the Makefile
# !apt-get install vim
# !ls
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   libgpm2 vim-common vim-runtime xxd
# Suggested packages:
#   gpm ctags vim-doc vim-scripts
# The following NEW packages will be installed:
#   libgpm2 vim vim-common vim-runtime xxd
# 0 upgraded, 5 newly installed, 0 to remove and 8 not upgraded.
# Need to get 6,721 kB of archives.
# After this operation, 32.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xxd amd64 2:8.0.1453-1ubuntu1.1 [49.2 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 vim-common all 2:8.0.1453-1ubuntu1.1 [70.4 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic/main amd64 libgpm2 amd64 1.20.7-5 [15.1 kB]
# ...

# %%
# %cd /content/darknet
#!vim Makefile GPU=1 CUDNN=1
# Out:
# /content/darknet

# %%
#!ls
#!wget https://pjreddie.com/media/files/yolov3.weights

# %%
# !ls
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# Out:
# 3rdparty	cfg			image_yolov2.sh        README.md
# anchors.txt	chart.png		image_yolov3.sh        results
# appveyor.yml	cmake			include		       scripts
# backup		CMakeLists.txt		json_mjpeg_streams.sh  src
# bad_label.list	darknet			LICENSE		       video_v2.sh
# bad.list	DarknetConfig.cmake.in	Makefile	       video_yolov3.sh
# build		darknet.py		net_cam_v3.sh	       yolov3.weights
# build.ps1	darknet_video.py	obj		       yolov3.weights.1
# build.sh	data			predictions.jpg

# %%
# !ls
# %cd ../
# !ls
# Out:
# 3rdparty	cfg			image_yolov2.sh        README.md
# anchors.txt	chart.png		image_yolov3.sh        results
# appveyor.yml	cmake			include		       scripts
# backup		CMakeLists.txt		json_mjpeg_streams.sh  src
# bad_label.list	darknet			LICENSE		       video_v2.sh
# bad.list	DarknetConfig.cmake.in	Makefile	       video_yolov3.sh
# build		darknet.py		net_cam_v3.sh	       yolov3.weights
# build.ps1	darknet_video.py	obj		       yolov3.weights.1
# build.sh	data			predictions.jpg
# /content
# content  darknet  darknet.zip  drive  sample_data

# %%
# !apt install g++-5
# !apt install gcc-5

# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 10
# !update-alternatives --install /usr/bin/gcc gcc /usr/bin/gcc-5 20
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 10
# !update-alternatives --install /usr/bin/g++ g++ /usr/bin/g++-5 20
# !update-alternatives --install /usr/bin/cc cc /usr/bin/gcc 30
# !update-alternatives --set cc /usr/bin/gcc
# !update-alternatives --install /usr/bin/c++ c++ /usr/bin/g++ 30
# !update-alternatives --set c++ /usr/bin/g++
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-430
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   cpp-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# Suggested packages:
#   gcc-5-locales g++-5-multilib gcc-5-doc libstdc++6-5-dbg gcc-5-multilib
#   libgcc1-dbg libgomp1-dbg libitm1-dbg libatomic1-dbg libasan2-dbg
#   liblsan0-dbg libtsan0-dbg libubsan0-dbg libcilkrts5-dbg libmpx0-dbg
#   libquadmath0-dbg libstdc++-5-doc
# The following NEW packages will be installed:
#   cpp-5 g++-5 gcc-5 gcc-5-base libasan2 libgcc-5-dev libisl15 libmpx0
#   libstdc++-5-dev
# 0 upgraded, 9 newly installed, 0 to remove and 8 not upgraded.
# Need to get 29.1 MB of archives.
# After this operation, 100 MB of additional disk space will be used.
# ...

# %%
#Now, here's a bunch of code that takes the longest to execute here but
#It's about installing CUDA and using the beautiful Tesla K80 GPU, so that
#Will worth it

# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !dpkg -i cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# !apt-get update -qq

#Here were are installing compilers and creating some links
# !apt-get install cuda -y -qq #gcc-5 g++-5 
#!ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc
#!ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++
# !apt update
# !apt upgrade
# !apt install cuda-8.0 -y
# Out:
# 8 packages can be upgraded. Run 'apt list --upgradable' to see them.
# --2020-01-24 09:16:00--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.162.216
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.162.216|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?u4r8UeKzouPCxZp4DcpeIQN_Fa3JeDshcBxILkmYNhbaHYhVx26y94lizedXrWcm7XxhV4MdnF_jblgk2a6nCnWKkOq3QrvBX9ieRCUsDODysEOzpCcVk4OAozO9l5inEfc_PSU6FOLcQxGLkKYRJdoLVjpX3jfVb7n6CbR2uLSMFa0fbnDamSi1V50e0R8zHnWeEcIpCHQUAnxT415tdros9g [following]
# ...

# %%
#Now let's see whether the GPU is here and CUDA was successfully installed!
import tensorflow as tf
device_name = tf.test.gpu_device_name()
print(device_name)

print("'sup!'")

# !/usr/local/cuda/bin/nvcc --version
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>
# /device:GPU:0
# 'sup!'
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2016 NVIDIA Corporation
# Built on Tue_Jan_10_13:22:03_CST_2017
# Cuda compilation tools, release 8.0, V8.0.61

# %%
# %cd /content/darknet
# !make
# Out:
# /content/darknet
# chmod +x *.sh
# g++ -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:908:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^
# ./src/image_opencv.cpp: In function ‘image image_data_augmentation(void**, int, int, int, int, int, int, int, float, float, float, int, int, float*)’:
# ./src/image_opencv.cpp:1217:26: warning: variable ‘kernel_size’ set but not used [-Wunused-but-set-variable]
#                  cv::Size kernel_size = cv::Size(ksize, ksize);
#                           ^
# ./src/image_opencv.cpp: At global scope:
# ...

# %%
# %pwd

# %%
# %cd /content

# %%
from zipfile import ZipFile
file_name = "images_1.zip"


with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')

# %%
# %cd /content/darknet/build/darknet/x64/data
# !ls

# %%
# !python split_train_test.py

# %%
# !ls
# %pwd

# %%
import shutil 

sourceDir = '/content/madurai-traffic-counter-master/madurai-traffic-counter-master/yolo-coco/yolov3-obj.cfg'

destDir =  '/content/drive/My Drive/'

shutil.copy(sourceDir, destDir)

# %%
import shutil 

sourceDir = '/content/darknet/build/darknet/x64/backup/'

destDir =  '/content/drive/My Drive/content/yolov3-obj_last.weights'
shutil.copy(destDir,sourceDir)

# %%
# %pwd
# %cd /content

# %%
from zipfile import ZipFile
file_name = "madurai-traffic-counter-master.zip"


with ZipFile(file_name,'r') as zip:
  zip.extractall()
  print('Done')

# %%
import shutil 

sourceDir = '/content/yolov3-obj.cfg'
source = '/content/obj.names'
scr = '/content/darknet/build/darknet/x64/backup/yolov3-obj_4000.weights'

destDir =  '/content/darknet/build/darknet/x64/data/'
#shutil.copy(sourceDir, destDir)
shutil.copy(source, destDir)
#shutil.copy(scr, destDir)

# %%
# %cd madurai-traffic-counter-master

# %%
# !pip install filterpy

# %%
# !python main.py --input input/highway.mp4 --output output/result.avi --yolo yolo-coco

# %%
# !pip install -r requirements.txt

# %%
import shutil 

sourceDir = '/content/obj.data'
source = '/content/obj.names'
destDir =  '/content/darknet/build/darknet/x64/data/'
shutil.move(sourceDir, destDir)
shutil.move(source, destDir)

# %%
import shutil 

sourceDir = '/content/yolov3-obj.cfg'
destDir =  '/content/darknet/build/darknet/x64/'
shutil.move(sourceDir, destDir)

# %%
# !sudo rm -rf ~/.nv

# %%
# %cd /content/
# !ls

# %%
# !./darknet detector calc_anchors "/content/darknet/build/darknet/x64/data/obj.data" -num_of_clusters 9 -width 416 -height 416

# %%
#%pwd
# %cd /content/darknet

# %%
#%pwd

# %%
# !./darknet detector train "/content/darknet/build/darknet/x64/data/obj.data" "/content/darknet/build/darknet/x64/yolov3-obj.cfg" "/content/darknet/build/darknet/x64/darknet53.conv.74" -dont_show

# %%
# !./darknet detector train "/content/darknet/build/darknet/x64/data/obj.data" "/content/darknet/build/darknet/x64/yolov3-obj.cfg" "/content/darknet/build/darknet/x64/backup/yolov3-obj_8000.weights" -dont_show
# Out:
# yolov3-obj
# net.optimized_memory = 0
# batch = 8, time_steps = 1, train = 1
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
# ...

# %%
# !./darknet detector train "/content/darknet/build/darknet/x64/data/obj.data" "/content/darknet/build/darknet/x64/yolov3-obj.cfg" "/content/darknet/build/darknet/x64/backup/yolov3-obj_1000.weights" -dont_show

# %%
# !./darknet detector train "/content/darknet/build/darknet/x64/data/obj.data" "/content/darknet/build/darknet/x64/yolov3-obj.cfg" "/content/darknet/build/darknet/x64/backup/yolov3-obj_2000.weights" -dont_show

# %%
#Let's define some functions that will let us show images, and upload and 
#download files
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  #plt.rcParams['figure.figsize'] = [10, 5]
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))
  plt.show()
  
  
def upload():
  from google.colab import files
  uploaded = files.upload() 
  for name, data in uploaded.items():
    with open(name, 'wb') as f:
      f.write(data)
      print ('saved file', name)
def download(path):
  from google.colab import files
  files.download(path)

# %%
#darknet detector test data/obj.data yolo-obj.cfg yolo-obj_8000.weights
# !./darknet detector test  "/content/darknet/build/darknet/x64/data/obj.data" "/content/darknet/build/darknet/x64/yolov3-obj.cfg" "/content/darknet/build/darknet/x64/backup/yolov3-obj_2000.weights" "/content/darknet/build/darknet/x64/data/obj/166.jpg" -dont_show -i 0 -thresh 0.15
imShow('predictions.jpg')

# %%
# !zip -r /content/darknet.zip /content/darknet
# Out:
#   adding: content/darknet/ (stored 0%)
#   adding: content/darknet/src/ (stored 0%)
#   adding: content/darknet/src/conv_lstm_layer.h (deflated 66%)
#   adding: content/darknet/src/yolo.c (deflated 74%)
#   adding: content/darknet/src/gaussian_yolo_layer.c (deflated 81%)
#   adding: content/darknet/src/.editorconfig (deflated 19%)
#   adding: content/darknet/src/activation_layer.c (deflated 72%)
#   adding: content/darknet/src/rnn_layer.h (deflated 63%)
#   adding: content/darknet/src/detection_layer.c (deflated 79%)
#   adding: content/darknet/src/version.h (deflated 39%)
#   adding: content/darknet/src/parser.h (deflated 64%)
#   adding: content/darknet/src/matrix.c (deflated 74%)
#   adding: content/darknet/src/route_layer.c (deflated 81%)
#   adding: content/darknet/src/utils.h (deflated 67%)
#   adding: content/darknet/src/blas.c (deflated 77%)
#   adding: content/darknet/src/cpu_gemm.c (deflated 81%)
#   adding: content/darknet/src/batchnorm_layer.c (deflated 81%)
# ...

# %%
# !./darknet detector demo  "/content/darknet/build/darknet/x64/data/obj.data" "/content/darknet/build/darknet/x64/yolov3-obj.cfg" "/content/darknet/build/darknet/x64/backup/yolov3-obj_4000.weights" -dont_show "/content/drive/My Drive/test3.mp4" -out_filename "/content/result_final.mp4"
# Out:
# Demo
# net.optimized_memory = 0
# batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
#    6 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#    7 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#    8 Shortcut Layer: 5
#    9 conv     64       1 x 1/ 1    104 x 104 x 128 ->  104 x 104 x  64 0.177 BF
#   10 conv    128       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x 128 1.595 BF
#   11 Shortcut Layer: 8
# ...

# %%
# !./darknet detector test "/content/darknet/build/darknet/x64/data/obj.data" "/content/darknet/build/darknet/x64/yolov3-obj.cfg" "/content/darknet/build/darknet/x64/backup/yolov3-tiny-obj_4000.weights"

# %%
import shutil 

sourceDir = '/content/drive/My Drive/'
destDir =  '/content/darknet_3.zip'
shutil.move(sourceDir, destDir)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive

# %%
# !ls

# %%
cd My Drive

# %%
!%cd /content/darknet/
# !ls

# %%
# %cd /content/darknet/Bike-Auto
# !ls

# %%
import shutil 

destDir = '/content/darknet/build/darknet/x64/data/'
sourceDir =  '/content/obj.names'
shutil.move(sourceDir, destDir)

# %%
# %cd /content/darknet
# !ls

# %%
# %cd cfg
# !ls

# %%
# %cd /content
# !ls

# %%
# %cd /content
# !ls

# %%
import shutil 

sourceDir = '/content/yolov3-tiny.cfg'
destDir =  '/content/darknet/cfg/'
shutil.copy(sourceDir, destDir)

# %%
# %cd /content
# !ls

# %%
import shutil 

sourceDir = '/content/darknet53.conv.74'
destDir =  '/content/darknet/'
shutil.copy(sourceDir, destDir)

# %%
# %pwd

# %%
# !apt-get install libopencv-highgui-dev

# %%
# !./darknet detector train "/content/darknet/cfg/obj.data" "/content/darknet/cfg/yolov3-tiny.cfg" "/content/darknet/darknet53.conv.74"
